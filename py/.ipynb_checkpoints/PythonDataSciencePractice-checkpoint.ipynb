# %%
import numpy as np
import pandas as pd
df = pd.read_csv('C:/Users/ashle/GitHub/DataScience/data/formex.csv', encoding='latin-1')
df.head()

# %%
# Out:
#                               subj ctrb gender  age group    exp data enterer  \
# 0  2N/351K (DNU - failed posttest)  513      M          5  Melis      Ariella
# 1                               3N  513      M          5  Melis      Ariella
# 2                               6N  502      F          5  Melis      Ariella
# 3                               7N  509      F          5  Melis      Ariella
# 4       8N (DNU - failed posttest)  510      F          5  Melis      Ariella
#
#          dob        dot  age exact  \
# 0  5/31/2013  5/31/2018      5.000
# 1   5/7/2013   6/3/2018      5.072
# 2  11/7/2012   6/3/2018      5.572
# 3  2/22/2013   6/3/2018      5.281
# 4  3/11/2013   6/3/2018      5.228
#
#                                       race/ethnicity  ...    \
# 0  Caucasian, not of Hispanic origin; Asian or Pa...  ...
# 1                                          Caucasian  ...
# 2                                                NaN  ...
# ...
